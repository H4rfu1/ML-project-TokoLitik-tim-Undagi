# %% [markdown]
# ####  IMPORT REQUIRED PACKAGES

# %%
import json
import requests

# %% [markdown]
# #### Set the product ID
# User can put any product ID to be analyzed

# %%
productID = 1
URL = 'http://kulacino.my.id:3000/api/users/stores/products/{}/transactions/'.format(productID)
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjEsImlhdCI6MTYyMTcxOTM5OSwiZXhwIjoxNjIxODA1Nzk5fQ.nV1ZFebs133B0QGATM7gaqwT-cWOvNFbcrpvYRDqdFo'
my_headers = {'auth-token' : '{}'.format(token)}

# %% [markdown]
# #### Authentication Request

# %%
response = requests.get(URL, headers=my_headers)
if(response.status_code == 200):
    print("Authentication succeed")
else:
    print("Authentication failed (make sure your token is valid and no network issue)")
# Out:
# Authentication succeed

# %%
response.json()
# Out:
# {'transaction': [{'id': 1,
#    'productId': 1,
#    'time': '2015-01-12T00:00:00.000Z',
#    'amount': 125,
#    'createdAt': '2021-05-22T11:45:21.000Z',
#    'updatedAt': '2021-05-22T11:45:21.000Z'},
#   {'id': 2,
#    'productId': 1,
#    'time': '2015-02-12T00:00:00.000Z',
#    'amount': 70,
#    'createdAt': '2021-05-22T11:45:21.000Z',
#    'updatedAt': '2021-05-22T11:45:21.000Z'},
#   {'id': 3,
#    'productId': 1,
#    'time': '2015-03-12T00:00:00.000Z',
#    'amount': 41,
#    'createdAt': '2021-05-22T11:45:21.000Z',
#    'updatedAt': '2021-05-22T11:45:21.000Z'},
#   {'id': 4,
#    'productId': 1,
#    'time': '2015-04-12T00:00:00.000Z',
#    'amount': 62,
#    'createdAt': '2021-05-22T11:45:21.000Z',
#    'updatedAt': '2021-05-22T11:45:21.000Z'},
#   {'id': 5,
#    'productId': 1,
#    'time': '2015-05-12T00:00:00.000Z',
#    'amount': 50,
#    'createdAt': '2021-05-22T11:45:21.000Z',
#    'updatedAt': '2021-05-22T11:45:21.000Z'},
#   {'id': 6,
#    'productId': 1,
# ...

# %% [markdown]
# #### Dataset Preparation

# %%
data = []
transaction = response.json()["transaction"]
product = response.json()["product"]

for i in transaction:
    temp = {"date": i["time"],
            "daily_sales": i["amount"]}
    data.append(temp)

# %% [markdown]
# #### Export Dataset as Json File

# %%
jsonString = json.dumps(data)
jsonFile = open("data.json", "w")
jsonFile.write(jsonString)
jsonFile.close()

# %%
jsonString = json.dumps(product)
jsonFile = open("product.json", "w")
jsonFile.write(jsonString)
jsonFile.close()

# %%
jsonString = json.dumps(transaction)
jsonFile = open("transaction.json", "w")
jsonFile.write(jsonString)
jsonFile.close()
